# %%
# !gdown 1DyzESaLXGz4qQASslNJxuPXjRhw7LviG
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1DyzESaLXGz4qQASslNJxuPXjRhw7LviG
# To: /content/Dataset_02.zip
# 100% 888M/888M [00:18<00:00, 47.1MB/s]

# %%
# !unzip Dataset_02.zip
# Out:
# Archive:  Dataset_02.zip
#    creating: Testing/Roughbark/
#   inflating: Testing/Roughbark/IMG_4870.JPG
#   inflating: Testing/Roughbark/IMG_4874.JPG
#   inflating: Testing/Roughbark/IMG_4893.JPG
#   inflating: Testing/Roughbark/IMG_E4781.JPG
#   inflating: Testing/Roughbark/IMG_E4783.JPG
#   inflating: Testing/Roughbark/IMG_E4785.JPG
#   inflating: Testing/Roughbark/IMG_E4787.JPG
#   inflating: Testing/Roughbark/IMG_E4789.JPG
#   inflating: Testing/Roughbark/IMG_E4791.JPG
#   inflating: Testing/Roughbark/IMG_E4793.JPG
#   inflating: Testing/Roughbark/IMG_E4795.JPG
#   inflating: Testing/Roughbark/IMG_E4797.JPG
#   inflating: Testing/Roughbark/IMG_E4804.JPG
#   inflating: Testing/Roughbark/IMG_E4806.JPG
#   inflating: Testing/Roughbark/IMG_E4808.JPG
#   inflating: Testing/Roughbark/IMG_E4810.JPG
#   inflating: Testing/Roughbark/IMG_E4812.JPG
#   inflating: Testing/Roughbark/IMG_E4814.JPG
#   inflating: Testing/Roughbark/IMG_E4827.JPG
#   inflating: Testing/Roughbark/IMG_E4829.JPG
#   inflating: Testing/Roughbark/IMG_E4831.JPG
#   inflating: Testing/Roughbark/IMG_E4833.JPG
#   inflating: Testing/Roughbark/IMG_E4836.JPG
#   inflating: Testing/Roughbark/IMG_E4838.JPG
#   inflating: Testing/Roughbark/IMG_E4849.JPG
#   inflating: Testing/Roughbark/IMG_E4853.JPG
#   inflating: Testing/Roughbark/IMG_E4855.JPG
#   inflating: Testing/Roughbark/IMG_E4857.JPG
#   inflating: Testing/Roughbark/IMG_E4859.JPG
#   inflating: Testing/Roughbark/IMG_E4861.JPG
#   inflating: Testing/Roughbark/IMG_E4863.JPG
#   inflating: Testing/Roughbark/IMG_E4866.JPG
#   inflating: Testing/Roughbark/IMG_E4868.JPG
#    creating: Testing/Stripecanker/
#   inflating: Testing/Stripecanker/IMG_1717.JPG
#   inflating: Testing/Stripecanker/IMG_1771.JPG
#   inflating: Testing/Stripecanker/IMG_1773.JPG
#   inflating: Testing/Stripecanker/IMG_1775.JPG
#   inflating: Testing/Stripecanker/IMG_1777.JPG
#   inflating: Testing/Stripecanker/IMG_1779.JPG
#   inflating: Testing/Stripecanker/IMG_1781.JPG
#   inflating: Testing/Stripecanker/IMG_1783.JPG
#   inflating: Testing/Stripecanker/IMG_1808.JPG
#   inflating: Testing/Stripecanker/IMG_1874.JPG
#   inflating: Testing/Stripecanker/IMG_4799.JPG
#   inflating: Testing/Stripecanker/IMG_4801.JPG
#   inflating: Testing/Stripecanker/IMG_4803.JPG
#   inflating: Testing/Stripecanker/IMG_4817.JPG
#   inflating: Testing/Stripecanker/IMG_4819.JPG
#   inflating: Testing/Stripecanker/IMG_4875.JPG
#   inflating: Testing/Stripecanker/IMG_4878.JPG
#   inflating: Testing/Stripecanker/IMG_4880.JPG
#   inflating: Testing/Stripecanker/IMG_4882.JPG
#   inflating: Testing/Stripecanker/IMG_4884.JPG
#   inflating: Testing/Stripecanker/IMG_4886.JPG
#   inflating: Testing/Stripecanker/IMG_4888.JPG
#   inflating: Testing/Stripecanker/IMG_4890.JPG
#   inflating: Testing/Stripecanker/IMG_E4799.JPG
#   inflating: Testing/Stripecanker/IMG_E4801.JPG
#   inflating: Testing/Stripecanker/IMG_E4803.JPG
#   inflating: Testing/Stripecanker/IMG_E4818.JPG
#   inflating: Testing/Stripecanker/IMG_E4875.JPG
#   inflating: Testing/Stripecanker/IMG_E4877.JPG
#   inflating: Testing/Stripecanker/IMG_E4879.JPG
#   inflating: Testing/Stripecanker/IMG_E4881.JPG
#   inflating: Testing/Stripecanker/IMG_E4883.JPG
#   inflating: Testing/Stripecanker/IMG_E4885.JPG
#   inflating: Testing/Stripecanker/IMG_E4887.JPG
#   inflating: Testing/Stripecanker/IMG_E4889.JPG
#   inflating: Testing/Stripecanker/IMG_E4891.JPG
#  extracting: Testing/Stripecanker/StripeCanker.zip
#    creating: Training/Roughbark/
#   inflating: Training/Roughbark/IMG_4796.JPG
#   inflating: Training/Roughbark/IMG_4797.JPG
#   inflating: Training/Roughbark/IMG_4798.JPG
#   inflating: Training/Roughbark/IMG_4804.JPG
#   inflating: Training/Roughbark/IMG_4805.JPG
#   inflating: Training/Roughbark/IMG_4806.JPG
#   inflating: Training/Roughbark/IMG_4807.JPG
#   inflating: Training/Roughbark/IMG_4808.JPG
#   inflating: Training/Roughbark/IMG_4809.JPG
#   inflating: Training/Roughbark/IMG_4810.JPG
#   inflating: Training/Roughbark/IMG_4811.JPG
#   inflating: Training/Roughbark/IMG_4812.JPG
#   inflating: Training/Roughbark/IMG_4813.JPG
#   inflating: Training/Roughbark/IMG_4814.JPG
#   inflating: Training/Roughbark/IMG_4815.JPG
#   inflating: Training/Roughbark/IMG_4823.JPG
#   inflating: Training/Roughbark/IMG_4824.JPG
#   inflating: Training/Roughbark/IMG_4825.JPG
#   inflating: Training/Roughbark/IMG_4826.JPG
#   inflating: Training/Roughbark/IMG_4827.JPG
#   inflating: Training/Roughbark/IMG_4828.JPG
#   inflating: Training/Roughbark/IMG_4829.JPG
#   inflating: Training/Roughbark/IMG_4830.JPG
#   inflating: Training/Roughbark/IMG_4831.JPG
#   inflating: Training/Roughbark/IMG_4832.JPG
#   inflating: Training/Roughbark/IMG_4833.JPG
#   inflating: Training/Roughbark/IMG_4834.JPG
#   inflating: Training/Roughbark/IMG_4836.JPG
#   inflating: Training/Roughbark/IMG_4837.JPG
#   inflating: Training/Roughbark/IMG_4838.JPG
#   inflating: Training/Roughbark/IMG_4841.JPG
#   inflating: Training/Roughbark/IMG_4842.JPG
#   inflating: Training/Roughbark/IMG_4843.JPG
#   inflating: Training/Roughbark/IMG_4844.JPG
#   inflating: Training/Roughbark/IMG_4845.JPG
#   inflating: Training/Roughbark/IMG_4846.JPG
#   inflating: Training/Roughbark/IMG_4847.JPG
#   inflating: Training/Roughbark/IMG_4848.JPG
#   inflating: Training/Roughbark/IMG_4849.JPG
#   inflating: Training/Roughbark/IMG_4852.JPG
#   inflating: Training/Roughbark/IMG_4853.JPG
#   inflating: Training/Roughbark/IMG_4854.JPG
#   inflating: Training/Roughbark/IMG_4855.JPG
#   inflating: Training/Roughbark/IMG_4856.JPG
#   inflating: Training/Roughbark/IMG_4857.JPG
#   inflating: Training/Roughbark/IMG_4858.JPG
#   inflating: Training/Roughbark/IMG_4859.JPG
#   inflating: Training/Roughbark/IMG_4860.JPG
#   inflating: Training/Roughbark/IMG_4861.JPG
#   inflating: Training/Roughbark/IMG_4862.JPG
#   inflating: Training/Roughbark/IMG_4863.JPG
#   inflating: Training/Roughbark/IMG_4864.JPG
#   inflating: Training/Roughbark/IMG_4866.JPG
#   inflating: Training/Roughbark/IMG_4867.JPG
#   inflating: Training/Roughbark/IMG_4868.JPG
#   inflating: Training/Roughbark/IMG_4869.JPG
#   inflating: Training/Roughbark/IMG_4871.JPG
#   inflating: Training/Roughbark/IMG_4892.JPG
#   inflating: Training/Roughbark/IMG_E4780.JPG
#   inflating: Training/Roughbark/IMG_E4782.JPG
#   inflating: Training/Roughbark/IMG_E4784.JPG
#   inflating: Training/Roughbark/IMG_E4786.JPG
#   inflating: Training/Roughbark/IMG_E4788.JPG
#   inflating: Training/Roughbark/IMG_E4790.JPG
#   inflating: Training/Roughbark/IMG_E4792.JPG
#   inflating: Training/Roughbark/IMG_E4794.JPG
#   inflating: Training/Roughbark/IMG_E4796.JPG
#   inflating: Training/Roughbark/IMG_E4798.JPG
#   inflating: Training/Roughbark/IMG_E4805.JPG
#   inflating: Training/Roughbark/IMG_E4807.JPG
#   inflating: Training/Roughbark/IMG_E4809.JPG
#   inflating: Training/Roughbark/IMG_E4811.JPG
#   inflating: Training/Roughbark/IMG_E4813.JPG
#   inflating: Training/Roughbark/IMG_E4815.JPG
#   inflating: Training/Roughbark/IMG_E4828.JPG
#   inflating: Training/Roughbark/IMG_E4830.JPG
#   inflating: Training/Roughbark/IMG_E4832.JPG
#   inflating: Training/Roughbark/IMG_E4834.JPG
#   inflating: Training/Roughbark/IMG_E4837.JPG
#   inflating: Training/Roughbark/IMG_E4841.JPG
#   inflating: Training/Roughbark/IMG_E4842.JPG
#   inflating: Training/Roughbark/IMG_E4843.JPG
#   inflating: Training/Roughbark/IMG_E4844.JPG
#   inflating: Training/Roughbark/IMG_E4845.JPG
#   inflating: Training/Roughbark/IMG_E4847.JPG
#   inflating: Training/Roughbark/IMG_E4848.JPG
#   inflating: Training/Roughbark/IMG_E4852.JPG
#   inflating: Training/Roughbark/IMG_E4854.JPG
#   inflating: Training/Roughbark/IMG_E4856.JPG
#   inflating: Training/Roughbark/IMG_E4858.JPG
#   inflating: Training/Roughbark/IMG_E4860.JPG
#   inflating: Training/Roughbark/IMG_E4862.JPG
#   inflating: Training/Roughbark/IMG_E4864.JPG
#   inflating: Training/Roughbark/IMG_E4867.JPG
#   inflating: Training/Roughbark/IMG_E4869.JPG
#   inflating: Training/Roughbark/IMG_E4870.JPG
#   inflating: Training/Roughbark/IMG_E4871.JPG
#   inflating: Training/Roughbark/IMG_E4874.JPG
#   inflating: Training/Roughbark/IMG_E4892.JPG
#   inflating: Training/Roughbark/IMG_E4893.JPG
#    creating: Training/Stripecanker/
#   inflating: Training/Stripecanker/IMG_1607.JPG
#   inflating: Training/Stripecanker/IMG_1612.JPG
#   inflating: Training/Stripecanker/IMG_1613.JPG
#   inflating: Training/Stripecanker/IMG_1614.JPG
#   inflating: Training/Stripecanker/IMG_1616.JPG
#   inflating: Training/Stripecanker/IMG_1618.JPG
#   inflating: Training/Stripecanker/IMG_1619.JPG
#   inflating: Training/Stripecanker/IMG_1620.JPG
#   inflating: Training/Stripecanker/IMG_1621.JPG
#   inflating: Training/Stripecanker/IMG_1622.JPG
#   inflating: Training/Stripecanker/IMG_1623.JPG
#   inflating: Training/Stripecanker/IMG_1624.JPG
#   inflating: Training/Stripecanker/IMG_1625.JPG
#   inflating: Training/Stripecanker/IMG_1626.JPG
#   inflating: Training/Stripecanker/IMG_1627.JPG
#   inflating: Training/Stripecanker/IMG_1628.JPG
#   inflating: Training/Stripecanker/IMG_1629.JPG
#   inflating: Training/Stripecanker/IMG_1630.JPG
#   inflating: Training/Stripecanker/IMG_1631.JPG
#   inflating: Training/Stripecanker/IMG_1632.JPG
#   inflating: Training/Stripecanker/IMG_1633.JPG
#   inflating: Training/Stripecanker/IMG_1634.JPG
#   inflating: Training/Stripecanker/IMG_1635.JPG
#   inflating: Training/Stripecanker/IMG_1636.JPG
#   inflating: Training/Stripecanker/IMG_1637.JPG
#   inflating: Training/Stripecanker/IMG_1638.JPG
#   inflating: Training/Stripecanker/IMG_1639.JPG
#   inflating: Training/Stripecanker/IMG_1640.JPG
#   inflating: Training/Stripecanker/IMG_1641.JPG
#   inflating: Training/Stripecanker/IMG_1642.JPG
#   inflating: Training/Stripecanker/IMG_1643.JPG
#   inflating: Training/Stripecanker/IMG_1644.JPG
#   inflating: Training/Stripecanker/IMG_1645.JPG
#   inflating: Training/Stripecanker/IMG_1646.JPG
#   inflating: Training/Stripecanker/IMG_1647.JPG
#   inflating: Training/Stripecanker/IMG_1648.JPG
#   inflating: Training/Stripecanker/IMG_1649.JPG
#   inflating: Training/Stripecanker/IMG_1650.JPG
#   inflating: Training/Stripecanker/IMG_1651.JPG
#   inflating: Training/Stripecanker/IMG_1652.JPG
#   inflating: Training/Stripecanker/IMG_1653.JPG
#   inflating: Training/Stripecanker/IMG_1654.JPG
#   inflating: Training/Stripecanker/IMG_1657.JPG
#   inflating: Training/Stripecanker/IMG_1658.JPG
#   inflating: Training/Stripecanker/IMG_1659.JPG
#   inflating: Training/Stripecanker/IMG_1660.JPG
#   inflating: Training/Stripecanker/IMG_1661.JPG
#   inflating: Training/Stripecanker/IMG_1662.JPG
#   inflating: Training/Stripecanker/IMG_1663.JPG
#   inflating: Training/Stripecanker/IMG_1664.JPG
#   inflating: Training/Stripecanker/IMG_1665.JPG
#   inflating: Training/Stripecanker/IMG_1666.JPG
#   inflating: Training/Stripecanker/IMG_1667.JPG
#   inflating: Training/Stripecanker/IMG_1668.JPG
#   inflating: Training/Stripecanker/IMG_1669.JPG
#   inflating: Training/Stripecanker/IMG_1670.JPG
#   inflating: Training/Stripecanker/IMG_1671.JPG
#   inflating: Training/Stripecanker/IMG_1676.JPG
#   inflating: Training/Stripecanker/IMG_1677.JPG
#   inflating: Training/Stripecanker/IMG_1678.JPG
#   inflating: Training/Stripecanker/IMG_1679.JPG
#   inflating: Training/Stripecanker/IMG_1680.JPG
#   inflating: Training/Stripecanker/IMG_1681.JPG
#   inflating: Training/Stripecanker/IMG_1682.JPG
#   inflating: Training/Stripecanker/IMG_1683.JPG
#   inflating: Training/Stripecanker/IMG_1684.JPG
#   inflating: Training/Stripecanker/IMG_1703.JPG
#   inflating: Training/Stripecanker/IMG_1705.JPG
#   inflating: Training/Stripecanker/IMG_1707.JPG
#   inflating: Training/Stripecanker/IMG_1716.JPG
#   inflating: Training/Stripecanker/IMG_1762.JPG
#   inflating: Training/Stripecanker/IMG_1772.JPG
#   inflating: Training/Stripecanker/IMG_1774.JPG
#   inflating: Training/Stripecanker/IMG_1776.JPG
#   inflating: Training/Stripecanker/IMG_1778.JPG
#   inflating: Training/Stripecanker/IMG_1780.JPG
#   inflating: Training/Stripecanker/IMG_1782.JPG
#   inflating: Training/Stripecanker/IMG_1784.JPG
#   inflating: Training/Stripecanker/IMG_1812.JPG
#   inflating: Training/Stripecanker/IMG_1875.JPG
#   inflating: Training/Stripecanker/IMG_4800.JPG
#   inflating: Training/Stripecanker/IMG_4802.JPG
#   inflating: Training/Stripecanker/IMG_4816.JPG
#   inflating: Training/Stripecanker/IMG_4818.JPG
#   inflating: Training/Stripecanker/IMG_4820.JPG
#   inflating: Training/Stripecanker/IMG_4877.JPG
#   inflating: Training/Stripecanker/IMG_4879.JPG
#   inflating: Training/Stripecanker/IMG_4881.JPG
#   inflating: Training/Stripecanker/IMG_4883.JPG
#   inflating: Training/Stripecanker/IMG_4885.JPG
#   inflating: Training/Stripecanker/IMG_4887.JPG
#   inflating: Training/Stripecanker/IMG_4889.JPG
#   inflating: Training/Stripecanker/IMG_4891.JPG
#   inflating: Training/Stripecanker/IMG_E4800.JPG
#   inflating: Training/Stripecanker/IMG_E4802.JPG
#   inflating: Training/Stripecanker/IMG_E4816.JPG
#   inflating: Training/Stripecanker/IMG_E4820.JPG
#   inflating: Training/Stripecanker/IMG_E4876.JPG
#   inflating: Training/Stripecanker/IMG_E4878.JPG
#   inflating: Training/Stripecanker/IMG_E4880.JPG
#   inflating: Training/Stripecanker/IMG_E4882.JPG
#   inflating: Training/Stripecanker/IMG_E4884.JPG
#   inflating: Training/Stripecanker/IMG_E4886.JPG
#   inflating: Training/Stripecanker/IMG_E4888.JPG
#   inflating: Training/Stripecanker/IMG_E4890.JPG
#    creating: validation/Roughbark/
#   inflating: validation/Roughbark/IMG_1563.JPG
#   inflating: validation/Roughbark/IMG_1564.JPG
#   inflating: validation/Roughbark/IMG_1668.JPG
#   inflating: validation/Roughbark/IMG_1887.JPG
#   inflating: validation/Roughbark/IMG_1944.JPG
#   inflating: validation/Roughbark/IMG_1964.JPG
#   inflating: validation/Roughbark/IMG_1965.JPG
#   inflating: validation/Roughbark/IMG_2010.JPG
#   inflating: validation/Roughbark/IMG_2044.JPG
#   inflating: validation/Roughbark/IMG_2058.JPG
#   inflating: validation/Roughbark/IMG_2098.JPG
#   inflating: validation/Roughbark/IMG_4780.JPG
#   inflating: validation/Roughbark/IMG_4782.JPG
#   inflating: validation/Roughbark/IMG_4783.JPG
#   inflating: validation/Roughbark/IMG_4784.JPG
#   inflating: validation/Roughbark/IMG_4785.JPG
#   inflating: validation/Roughbark/IMG_4786.JPG
#   inflating: validation/Roughbark/IMG_4787.JPG
#   inflating: validation/Roughbark/IMG_4788.JPG
#   inflating: validation/Roughbark/IMG_4789.JPG
#   inflating: validation/Roughbark/IMG_4790.JPG
#   inflating: validation/Roughbark/IMG_4791.JPG
#   inflating: validation/Roughbark/IMG_4792.JPG
#   inflating: validation/Roughbark/IMG_4793.JPG
#   inflating: validation/Roughbark/IMG_4795.JPG
#    creating: validation/Stripecanker/
#   inflating: validation/Stripecanker/IMG_1548.JPG
#   inflating: validation/Stripecanker/IMG_1549.JPG
#   inflating: validation/Stripecanker/IMG_1550.JPG
#   inflating: validation/Stripecanker/IMG_1551.JPG
#   inflating: validation/Stripecanker/IMG_1552.JPG
#   inflating: validation/Stripecanker/IMG_1553.JPG
#   inflating: validation/Stripecanker/IMG_1554.JPG
#   inflating: validation/Stripecanker/IMG_1555.JPG
#   inflating: validation/Stripecanker/IMG_1556.JPG
#   inflating: validation/Stripecanker/IMG_1557.JPG
#   inflating: validation/Stripecanker/IMG_1558.JPG
#   inflating: validation/Stripecanker/IMG_1559.JPG
#   inflating: validation/Stripecanker/IMG_1565.JPG
#   inflating: validation/Stripecanker/IMG_1566.JPG
#   inflating: validation/Stripecanker/IMG_1567.JPG
#   inflating: validation/Stripecanker/IMG_1568.JPG
#   inflating: validation/Stripecanker/IMG_1571.JPG
#   inflating: validation/Stripecanker/IMG_1572.JPG
#   inflating: validation/Stripecanker/IMG_1573.JPG
#   inflating: validation/Stripecanker/IMG_1574.JPG
#   inflating: validation/Stripecanker/IMG_1575.JPG
#   inflating: validation/Stripecanker/IMG_1584.JPG
#   inflating: validation/Stripecanker/IMG_1604.JPG
#   inflating: validation/Stripecanker/IMG_1605.JPG
#   inflating: validation/Stripecanker/IMG_1606.JPG
#   inflating: validation/Stripecanker/IMG_1608.JPG
#   inflating: validation/Stripecanker/IMG_1611.JPG

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os 
import keras

from keras.preprocessing.image import ImageDataGenerator 
from tensorflow.keras.utils import img_to_array, load_img
from keras.applications.vgg19 import VGG19, preprocess_input, decode_predictions

# %%
os.listdir("/content/Training")
# Out:
# ['Roughbark', 'Stripecanker']

# %%
train_datagen = ImageDataGenerator(zoom_range=0.5, shear_range=0.4, rescale= 1/255, horizontal_flip = True, preprocessing_function= preprocess_input)

val_datagen = ImageDataGenerator(preprocessing_function= preprocess_input)

train = train_datagen.flow_from_directory(directory="/content/Training", target_size =(255,255), batch_size = 2)

val = val_datagen.flow_from_directory(directory="/content/validation", target_size =(255,255), batch_size = 2)
# Out:
# Found 205 images belonging to 2 classes.
# Found 52 images belonging to 2 classes.

# %%
t_img, label = train.next()
t_img.shape
# Out:
# (2, 255, 255, 3)

# %%
def plotImage(img_arr, label):
  for im, l in zip(img_arr, label):
    plt.figure(figsize = (5,5))
    plt.imshow(im)
    plt.show()

plotImage(t_img[:3], label[:3])
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
from keras.layers import Dense, Flatten
from keras.models import Model
from keras.applications.vgg19 import VGG19
import keras

base_model = VGG19(input_shape=(255,255,3), include_top=False)

for layer in base_model.layers:
  layer.trainable = False

base_model.summary()

x = Flatten()(base_model.output)

x = Dense(units= 2, activation='softmax')(x)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 3s 0us/step
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 255, 255, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 255, 255, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 255, 255, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 127, 127, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 127, 127, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 127, 127, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 63, 63, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 63, 63, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 63, 63, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 63, 63, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 63, 63, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 31, 31, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 31, 31, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 31, 31, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 31, 31, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 31, 31, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 15, 15, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 20,024,384
# Trainable params: 0
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
model = Model(base_model.input, x)

model.summary()

model.compile(optimizer='adam', loss=keras.losses.categorical_crossentropy, metrics=['accuracy'] )
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 255, 255, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 255, 255, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 255, 255, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 127, 127, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 127, 127, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 127, 127, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 63, 63, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 63, 63, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 63, 63, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 63, 63, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 63, 63, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 31, 31, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 31, 31, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 31, 31, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 31, 31, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 31, 31, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 15, 15, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  dense_1 (Dense)             (None, 2)                 50178
#
# =================================================================
# Total params: 20,074,562
# Trainable params: 50,178
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

es = EarlyStopping(monitor='val_accuracy', min_delta=0.01, patience=3, verbose=1 )

mc = ModelCheckpoint(filepath="best_model.h5",monitor='val_accuracy', min_delta=0.01, patience=3, verboss=1, save_best_only=True)

cb = [es,mc]

his = model.fit(train, steps_per_epoch=16, epochs = 50, verbose=1, callbacks=cb, validation_data=val, validation_steps=5  )

h = his.history
h.keys()
# Out:
# Epoch 1/50
# 16/16 [==============================] - 11s 536ms/step - loss: 0.9219 - accuracy: 0.8125 - val_loss: 3.0585 - val_accuracy: 0.9000
# Epoch 2/50
# 16/16 [==============================] - 8s 525ms/step - loss: 1.3783 - accuracy: 0.8438 - val_loss: 14.1715 - val_accuracy: 0.5000
# Epoch 3/50
# 16/16 [==============================] - 7s 466ms/step - loss: 0.4291 - accuracy: 0.9375 - val_loss: 13.6220 - val_accuracy: 0.7000
# Epoch 4/50
# 16/16 [==============================] - 8s 498ms/step - loss: 0.2074 - accuracy: 0.9688 - val_loss: 26.5627 - val_accuracy: 0.6000
# Epoch 4: early stopping
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'], c = "red")
plt.title("acc vs v-acc")
plt.show()

# %%
plt.plot(h['loss'])
plt.plot(h['val_loss'], c = "red")
plt.title("loss vs v-loss")
plt.show()

# %%
from keras.models import load_model

model = load_model("/content/best_model.h5")

acc = model.evaluate_generator(val)[1]

print(f"Accuracy of model: {acc*100} %")
# Out:
# <ipython-input-34-12d9c43cdb7c>:5: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   acc = model.evaluate_generator(val)[1]
# Accuracy of model: 71.15384340286255 %

# %%
model.save('acc71.h5')
